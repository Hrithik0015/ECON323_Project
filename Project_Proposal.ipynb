# %% [markdown]
# ## ECON 323 Final Project Proposal
# ### An Analysis of Airbnb Prices Across Popular Countries in Europe
#
#
# 1. Hrithik Soni (section 003)
# 2. Karina Grewal (section 004)

# %% [markdown]
# ### Introduction
# We will be looking into predicting the prices of Airbnb's in popular European destinations based on a variety of factors. The dataset also includes prices when it is the weekend in comparison to weekdays. Therefore this analysis will provide much insight into social/geological factors that reveal booking trends in Airbnb's across Europe.
#
# For this project, we will be using Python as the programming language to conduct the analysis.

# %% [markdown]
# ### Methods
# We will examine which variables are the most influential and build a prediction model using regression to predict Airbnb prices.
#
# **The Response Variable**
# * realSum (the total price of the listing)
#
# **Independent Variables**
#
# * room_type: the type of the accommodation
# * room_shared: dummy variable for shared rooms
# * room_private: dummy variable for private rooms
# * person_capacity: the maximum number of guests
# * host_is_superhost: dummy variable for superhost status
# * multi: dummy variable if the listing belongs to hosts with 2-4 offers
# * biz: dummy variable if the listing belongs to hosts with more than 4 offers
# * cleanliness_rating: cleanliness rating
# * guest_satisfaction_overall: overall rating of the listing
# * bedrooms: number of bedrooms (0 for studios)
# * dist: distance from city centre in km
# * metro_dist: distance from nearest metro station in km
# * attr_index: attraction index of the listing location
# * attr_index_norm: normalised attraction index (0-100)
# * rest_index: restaurant index of the listing location
# * attr_index_norm: normalised restaurant index (0-100)
# * lng: longitude of the listing location
# * lat: latitude of the listing location

# %% [markdown]
# ### A Peek at the Dataset

# %%
#loading necessary packages
#!pip install opendatasets
import opendatasets as od
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#downloading datasets to a local folder
od.download("https://www.kaggle.com/datasets/thedevastator/airbnb-prices-in-european-cities")
# Out:
# Skipping, found downloaded files in "./airbnb-prices-in-european-cities" (use force=True to force download)

# %%
#accessing one dataset to take a peek at the data
amsterdam_weekdays = pd.read_csv('airbnb-prices-in-european-cities/amsterdam_weekdays.csv')
amsterdam_weekdays.head()
# Out:
#    Unnamed: 0     realSum     room_type  room_shared  room_private  \
# 0           0  194.033698  Private room        False          True
# 1           1  344.245776  Private room        False          True
# 2           2  264.101422  Private room        False          True
# 3           3  433.529398  Private room        False          True
# 4           4  485.552926  Private room        False          True
#
#    person_capacity  host_is_superhost  multi  biz  cleanliness_rating  \
# 0              2.0              False      1    0                10.0
# 1              4.0              False      0    0                 8.0
# 2              2.0              False      0    1                 9.0
# 3              4.0              False      0    1                 9.0
# 4              2.0               True      0    0                10.0
#
#    guest_satisfaction_overall  bedrooms      dist  metro_dist  attr_index  \
# ...

# %% [markdown]
# ### Collaboration
#
# We will try to divide the work equally between us such that we both get an equal exposure in coding and writing.
#
# **Contribution**
#
# - Explanatory Data Analysis
#
#     We will split the plots that are required for data visualization. Each one of us will work independently to produce the plots and then we will meet to discuss about its interpretation.
#
#
# - Method
#
#     We will be using multiple methods to find the best model for prediction. We will work on each method individually and then discuss results (compare models).
#
# **Communication**
#
# - The main source of communication between us will be via zoom.
# - We will setup meeting times to share and discuss our results.
